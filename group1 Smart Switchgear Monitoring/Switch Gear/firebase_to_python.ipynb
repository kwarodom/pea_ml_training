# %%
import pyrebase
import random
import time
config = {
      "apiKey": "AIzaSyDytJNEPvKf5vnEvAcs4pr0u79kPqNhHSU",
      "authDomain": "anon-project-fb15f.firebaseapp.com",
      "databaseURL": "https://anon-project-fb15f.firebaseio.com",
      "projectId": "anon-project-fb15f",
      "storageBucket": "anon-project-fb15f.appspot.com",
      "messagingSenderId": "966608228277"
}

firebase = pyrebase.initialize_app(config)

db = firebase.database()

def stream_handler(message):
    print(message["event"]) # put
    print(message["path"]) # /-K7yGTTEp7O549EzTYtI
    print(message["data"]) # {'title': 'Pyrebase', "body": "etc..."}

my_stream = db.child("users").stream(stream_handler)
print(my_stream)
my_stream2 = db.child("member").stream(stream_handler)
print(my_stream2)
# Out:
# <pyrebase.pyrebase.Stream object at 0x0000017C4AC17470>
# <pyrebase.pyrebase.Stream object at 0x0000017C4AC17898>
# putput
# /
# {'0': {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}, '1': {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}, '2': {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}, '5': {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}, '6': {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}, '9': {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}, 'Morty': {'name': "Mortimer 'Morty' Smith"}, 'Rick': {'name': 'Rick Sanchez'}}
#
# /
# {'ipo_margin': 16, 'issue_reports': 16, 'logistics': 3, 'member_profit': 3, 'orders': 3, 'orders2': 3, 'payments': 3, 'revenue': 3, 'transactions': 3, 'weekly_orders': 1000}
# putput
# /8
# {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}
#
# /8
# {'email': 'kwarodom@vt.edu', 'profile_picture': 'https://pbs.twimg.com/profile_images/966896631147765760/AJ836huS_400x400.jpg', 'username': 'warodom khamphanchai'}
# putput
# /ipo_margin
# 10
#
# /ipo_margin
# 10
# put
# /issue_reports
# 10
# put
# /issue_reports
# 10
# put
# /member_profit
# 10
# put
# /member_profit
# 10
# putput
# /logistics
# 10
#
# /logistics
# 10
# put
# /orders
# 10
# put
# /orders
# 10
# put
# /payments
# 10
# put
# /payments
# 10
# put
# /revenue
# 10
# put
# /revenue
# 10
# putput
# /transactions
# 10
#
# /transactions
# 10
# putput
# /orders2
# 10
#
# /orders2
# 10
# put
# /ipo_margin
# 8
# put
# /ipo_margin
# 8
# putput
#
# /issue_reports
# 8
# /issue_reports
# 8
# put
# /member_profit
# 8
# put
# /member_profit
# 8
# put
# /logistics
# 8
# put
# /logistics
# 8
# putput
# /orders
# 8
#
# /orders
# 8
# putput
# /payments
# 8
#
# /payments
# 8
# put
# /revenue
# 8
# put
# /revenue
# 8
# putput
# /transactions
# 8
#
# /transactions
# 8
# putput
# /orders2
# 8
#
# /orders2
# 8
# putput
# /ipo_margin
# 14
#
# /ipo_margin
# 14
# putput
# /issue_reports
# 14
#
# /issue_reports
# 14
# putput
# /member_profit
# 14
#
# /member_profit
# 14
# put
# /logistics
# 14
# put
# /logistics
# 14
# put
# /orders
# 14
# put
# /orders
# 14
# put
# /payments
# 14
# put
# /payments
# 14
# put
# /revenue
# 14
# put
# /revenue
# 14
# put
# /transactions
# 14
# put
# /transactions
# 14
# put
# /orders2
# 14
# put
# /orders2
# 14
# putput
# /ipo_margin
# 16
#
# /ipo_margin
# 16
# putput
# /issue_reports
# 16
#
# /issue_reports
# 16
# putput
# /member_profit
# 16
#
# /member_profit
# 16
# putput
# /logistics
# /logistics
# 16
#
# 16
# putput
# /orders
# 16
#
# /orders
# 16
# putput
# /payments
# 16
#
# /payments
# 16
# putput
# /revenue
#
# 16
# /revenue
# 16
# put
# /transactions
# 16
# put
# /transactions
# 16
# put
# /orders2
# 16
# put
# /orders2
# 16
# putput
# /ipo_margin
# 9
#
# /ipo_margin
# 9
# putput
# /issue_reports
# 9
#
# /issue_reports
# 9
# put
# /member_profit
# 9
# put
# /member_profit
# 9
# put
# /logistics
# 9
# put
# /logistics
# 9
# put
# /orders
# 9
# put
# /orders
# 9
# putput
# /payments
# 9
#
# /payments
# 9
# put
# /revenue
# 9
# put
# /revenue
# 9
# putput
# /transactions
# 9
#
# /transactions
# 9
# put
# /orders2
# 9
# put
# /orders2
# 9
# put
# /ipo_margin
# 8
# put
# /ipo_margin
# 8
# put
# /issue_reports
# 8
# put
# /issue_reports
# 8
# put
# /member_profit
# 8
# put
# /member_profit
# 8
# put
# /logistics
# 8
# put
# /logistics
# 8
# put
# /orders
# 8
# put
# /orders
# 8
# putput
# /payments
# 8
#
# /payments
# 8
# put
# /revenue
# 8
# put
# /revenue
# 8
# put
# /transactions
# 8
# put
# /transactions
# 8
# put
# /orders2
# 8
# put
# /orders2
# 8
# put
# /ipo_margin
# 1
# put
# /ipo_margin
# 1
# put
# /issue_reports
# 1
# put
# /issue_reports
# 1
# put
# /member_profit
# 1
# put
# /member_profit
# 1
# put
# /logistics
# 1
# put
# /logistics
# 1
# put
# /orders
# 1
# put
# /orders
# 1
# putput
#
# /payments
# 1
# /payments
# 1
# put
# /revenue
# 1
# put
# /revenue
# 1
# put
# /transactions
# 1
# put
# /transactions
# 1
# put
# /orders2
# 1
# put
# /orders2
# 1
# putput
# /ipo_margin
# 19
#
# /ipo_margin
# 19
# put
# /issue_reports
# 19
# put
# /issue_reports
# 19
# put
# /member_profit
# 19
# put
# /member_profit
# 19
# putput
# /logistics
# 19
#
# /logistics
# 19
# put
# /orders
# 19
# put
# /orders
# 19
# put
# /payments
# 19
# put
# /payments
# 19
# putput
# /revenue
# 19
#
# /revenue
# 19
# putput
# /transactions
# 19
#
# /transactions
# 19
# put
# /orders2
# 19
# put
# /orders2
# 19
# put
# /ipo_margin
# 10
# put
# /ipo_margin
# 10
# putput
# /issue_reports
# 10
#
# /issue_reports
# 10
# putput
# /member_profit
# 10
#
# /member_profit
# 10
# putput
# /logistics
# 10
#
# /logistics
# 10
# putput
#
# /orders
# 10
# /orders
# 10
# putput
# /payments
# 10
#
# /payments
# 10
# put
# /revenue
# 10
# put
# /revenue
# 10
# putput
# /transactions
# 10
#
# /transactions
# 10
# put
# /orders2
# 10
# put
# /orders2
# 10
# put
# /ipo_margin
# 2
# put
# /ipo_margin
# 2
# put
# /issue_reports
# 2
# put
# /issue_reports
# 2
# put
# /member_profit
# 2
# put
# /member_profit
# 2
# put
# /logistics
# 2
# put
# /logistics
# 2
# put
# /orders
# 2
# put
# /orders
# 2
