# %%
import pyrebase
import random
import time
config = {
      "apiKey": "AIzaSyDytJNEPvKf5vnEvAcs4pr0u79kPqNhHSU",
      "authDomain": "anon-project-fb15f.firebaseapp.com",
      "databaseURL": "https://anon-project-fb15f.firebaseio.com",
      "projectId": "anon-project-fb15f",
      "storageBucket": "anon-project-fb15f.appspot.com",
      "messagingSenderId": "966608228277"
}

firebase = pyrebase.initialize_app(config)

db = firebase.database()

# # save data
# data = {"name": "Mortimer 'Morty' Smith"}
# db.child("users").push(data)

# update data

while True:
  random_x = random.randrange(1,20000)
  db.child("member").child("ipo_margin").set(random_x)
  db.child("member").child("issue_reports").set(random_x)
  db.child("member").child("member_profit").set(random_x)
  db.child("member").child("logistics").set(random_x)
  db.child("member").child("orders").set(random_x)
  db.child("member").child("payments").set(random_x)
  db.child("member").child("revenue").set(random_x)
  db.child("member").child("transactions").set(random_x)
  db.child("member").child("weekly_orders").set(random_x)
  time.sleep(2)

# #load setting
# db.child("load").child("h1").set(16853)
# db.child("load").child("h2").set(16450)
# db.child("load").child("h3").set(16517)
# db.child("load").child("h4").set(16873)
# db.child("load").child("h5").set(17064)
# db.child("load").child("h6").set(17727)
# db.child("load").child("h7").set(18574)
# db.child("load").child("h8").set(19355)
# db.child("load").child("h9").set(19534)
# db.child("load").child("h10").set(18611)
# db.child("load").child("h11").set(17666)
# db.child("load").child("h12").set(16374)
# db.child("load").child("h13").set(15106)
# db.child("load").child("h14").set(14455)
# db.child("load").child("h15").set(13518)
# db.child("load").child("h16").set(13138)
# db.child("load").child("h17").set(14130)
# db.child("load").child("h18").set(16809)
# db.child("load").child("h19").set(18150)
# db.child("load").child("h20").set(18235)
# db.child("load").child("h21").set(17925)
# db.child("load").child("h22").set(16904)
# db.child("load").child("h23").set(16162)
# db.child("load").child("h24").set(14750)

# #temp setting
# db.child("temp").child("h1").set(46)
# db.child("temp").child("h2").set(46)
# db.child("temp").child("h3").set(45)
# db.child("temp").child("h4").set(41)
# db.child("temp").child("h5").set(39)
# db.child("temp").child("h6").set(35)
# db.child("temp").child("h7").set(33)
# db.child("temp").child("h8").set(33)
# db.child("temp").child("h9").set(36)
# db.child("temp").child("h10").set(47)
# db.child("temp").child("h11").set(53)
# db.child("temp").child("h12").set(54)
# db.child("temp").child("h13").set(55)
# db.child("temp").child("h14").set(55)
# db.child("temp").child("h15").set(55)
# db.child("temp").child("h16").set(55)
# db.child("temp").child("h17").set(52)
# db.child("temp").child("h18").set(46)
# db.child("temp").child("h19").set(40)
# db.child("temp").child("h20").set(40)
# db.child("temp").child("h21").set(39)
# db.child("temp").child("h22").set(38)
# db.child("temp").child("h23").set(40)
# db.child("temp").child("h24").set(41)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\python36\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             try:  # Python 2.7, use buffering of HTTP responses
# --> 386                 httplib_response = conn.getresponse(buffering=True)
#     387             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c1a2f0559f73> in <module>()
#      30   db.child("member").child("payments").set(random_x)
#      31   db.child("member").child("revenue").set(random_x)
# ...
